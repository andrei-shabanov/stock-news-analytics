# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords

# df is the main dataset used in the project
df_news = pd.read_csv("https://raw.githubusercontent.com/EagleAdelaide/FinSen_Dataset/refs/heads/main/data.pptx/FinSen_US_Categorized_Timestamp.csv")

df_news.head(10)

# nasdaq_hist_data is the historical data of the NASDAQ 
nasdaq = yf.Ticker("^IXIC")

df_price = nasdaq.history(start="2015-06-01", end="2023-07-30")

df_price = df_price.reset_index()
df_price = df_price[['Date', 'Open', 'Close', 'Volume']]
# Out:
#                                                Title                  Tag  \
# 0              TSX Slightly Down, Books Weekly Gains         Stock Market
# 1                      UnitedHealth Hits 4-week High               stocks
# 2                      Cisco Systems Hits 4-week Low               stocks
# 3                             AT&T Hits All-time Low               stocks
# 4                         Microsoft Hits 4-week High               stocks
# 5                        JPMorgan Hits 16-month High               stocks
# 6           US Export Prices Fall More than Expected    Export Prices MoM
# 7  Citigroup earnings above expectations at 1.37 USD             Earnings
# 8              US Treasury Yields Below Recent Highs  Government Bond 10Y
# 9  Wells Fargo earnings above expectations at 1.2...             Earnings
#
#          Time                                            Content
# 0  16/07/2023  TSX Slightly Down, Books Weekly GainsUnited St...
# 1  15/07/2023  UnitedHealth Hits 4-week HighUnited States sto...
# 2  15/07/2023  Cisco Systems Hits 4-week LowUnited States sto...
# 3  15/07/2023  AT&T Hits All-time LowUnited States stocksAT&T...
# 4  15/07/2023  Microsoft Hits 4-week HighUnited States stocks...
# 5  15/07/2023  JPMorgan Hits 16-month HighUnited States stock...
# 6  15/07/2023  US Export Prices Fall More than ExpectedUnited...
# 7  15/07/2023  Citigroup earnings above expectations at 1.37 ...
# 8  15/07/2023  US Treasury Yields Below Recent Highs United S...
# 9  15/07/2023  Wells Fargo earnings above expectations at 1.2...
