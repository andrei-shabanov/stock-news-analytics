# %%
#%run 2.1_data_preparation_news.ipynb

# %%
# Setup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from wordcloud import WordCloud
import nltk
import re
import ast

# %%
df_news = pd.read_csv('./merged_df.csv')
df_news['Date_x'] = pd.to_datetime(df_news['Date_x'], format='ISO8601')
df_news['Date_y'] = pd.to_datetime(df_news['Date_y'], format='ISO8601')
df_news['Cleaned Content'] = df_news['Cleaned Content'].apply(ast.literal_eval)

# %%
print("Spalten:", df_news.columns.tolist())
print("Anzahl der Einträge:", len(df_news))


df_news.head(10)
# Out:
# Spalten: ['Title', 'Tag', 'Date_x', 'Content', 'Cleaned Content', 'Weekday', 'Impact Date', 'Date_y', 'Open', 'Close', 'Label', 'Change', 'Sma_5', 'Volatility', 'Prev_change', 'Simple Label', 'finbert_sentiment', 'finbert_label']
# Anzahl der Einträge: 13636
#                                                Title  \
# 0              TSX Slightly Down, Books Weekly Gains
# 1  US Budget Deficit Widens More than Expected in...
# 2                             Visa Hits 24-week High
# 3                           Amazon Hits 43-week High
# 4       10-Year Treasury Yield Falls for 4th Session
# 5                                 DXY Approaches 100
# 6               US Core PPI Rises Less than Expected
# 7  Progressive earnings below expectations at 0.5...
# 8    PepsiCo earnings above expectations at 2.09 USD
# 9  US Budget Deficit Widens More than Expected in...
#
#                         Tag     Date_x  \
# 0              Stock Market 2023-07-16
# 1   Government Budget Value 2023-07-14
# 2                    stocks 2023-07-14
# 3                    stocks 2023-07-14
# 4       Government Bond 10Y 2023-07-14
# 5                  Currency 2023-07-14
# 6  Core Producer Prices MoM 2023-07-14
# 7                  Earnings 2023-07-14
# 8                  Earnings 2023-07-14
# 9   Government Budget Value 2023-07-14
#
#                                              Content  \
# 0  TSX Slightly Down, Books Weekly GainsUnited St...
# 1  US Budget Deficit Widens More than Expected in...
# 2  Visa Hits 24-week HighUnited States stocksVisa...
# 3  Amazon Hits 43-week HighUnited States stocksAm...
# 4  10-Year Treasury Yield Falls for 4th SessionUn...
# 5  DXY Approaches 100United States CurrencyThe do...
# 6  US Core PPI Rises Less than ExpectedUnited Sta...
# 7  Progressive earnings below expectations at 0.5...
# 8  PepsiCo earnings above expectations at 2.09 US...
# 9  US Budget Deficit Widens More than Expected in...
#
#                                      Cleaned Content Weekday Impact Date  \
# 0  [tsx, slightly, books, weekly, gains, united, ...  Sunday  2023-07-17
# 1  [budget, deficit, widens, expected, june, unit...  Friday  2023-07-17
# 2  [visa, hits, week, high, united, states, stock...  Friday  2023-07-17
# 3  [amazon, hits, week, high, united, states, sto...  Friday  2023-07-17
# 4  [year, treasury, yield, falls, session, united...  Friday  2023-07-17
# 5  [approaches, united, states, currency, dollar,...  Friday  2023-07-17
# 6  [core, ppi, rises, less, expected, united, sta...  Friday  2023-07-17
# 7  [progressive, earnings, expectations, usd, uni...  Friday  2023-07-17
# 8  [pepsico, earnings, expectations, usd, united,...  Friday  2023-07-17
# 9  [budget, deficit, widens, expected, june, unit...  Friday  2023-07-17
#
#       Date_y          Open         Close  Label   Change         Sma_5  \
# 0 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
# 1 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
# 2 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
# 3 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
# 4 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
# 5 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
# 6 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
# 7 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
# 8 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
# 9 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
#
#    Volatility  Prev_change Simple Label  \
# 0  193.458381     0.009299     negative
# 1  193.458381     0.009299     negative
# 2  193.458381     0.009299     negative
# 3  193.458381     0.009299     negative
# 4  193.458381     0.009299     negative
# 5  193.458381     0.009299     negative
# 6  193.458381     0.009299     negative
# 7  193.458381     0.009299     negative
# 8  193.458381     0.009299     negative
# 9  193.458381     0.009299     negative
#
#                                    finbert_sentiment finbert_label
# 0  {'negative': np.float32(0.011293471), 'neutral...       neutral
# 1  {'negative': np.float32(0.6081924), 'neutral':...      negative
# 2  {'negative': np.float32(0.7537409), 'neutral':...      negative
# 3  {'negative': np.float32(0.5418749), 'neutral':...      negative
# 4  {'negative': np.float32(0.018656207), 'neutral...       neutral
# 5  {'negative': np.float32(0.10120035), 'neutral'...      positive
# 6  {'negative': np.float32(0.5960674), 'neutral':...      negative
# 7  {'negative': np.float32(0.037467457), 'neutral...       neutral
# 8  {'negative': np.float32(0.9225229), 'neutral':...      negative
# 9  {'negative': np.float32(0.6081924), 'neutral':...      negative

# %%
# Datum konvertieren
# df['date'] = pd.to_datetime(df['date']) # This column does not exist in the dataframe

# Textlänge berechnen
df_news['text_length'] = df_news['Content'].astype(str).apply(len) # Use 'Content' column

# Statistiken
print(df_news['text_length'].describe())

# Histogramm
sns.histplot(df_news['text_length'], bins=40, kde=True)
plt.title("Verteilung der Textlängen")
plt.xlabel("Zeichen")
plt.ylabel("Anzahl Texte")
plt.show()
# Out:
# count    13636.000000
# mean       511.542974
# std        279.115964
# min         77.000000
# 25%        213.000000
# 50%        493.000000
# 75%        735.250000
# max       1110.000000
# Name: text_length, dtype: float64

# %%
# Gruppierung nach Woche
weekly_counts = df_news.groupby(df_news['Date_x'].dt.to_period('W')).size()
weekly_counts.index = weekly_counts.index.to_timestamp()  # für saubere X-Achse im Plot

# Plot
weekly_counts.plot(figsize=(15, 5), title="Anzahl Nachrichten pro Woche")
plt.xlabel("Woche")
plt.ylabel("Anzahl Nachrichten")
plt.grid(True)
plt.show()

# %%
# Gruppieren nach Monat
monthly_counts = df_news.groupby(df_news['Date_x'].dt.to_period('M')).size()

# Optional: wieder zu Timestamp (für schöneres Plotten)
monthly_counts.index = monthly_counts.index.to_timestamp()

# Plot
monthly_counts.plot(figsize=(15,5), title="Anzahl Nachrichten pro Monat")
plt.xlabel("Monat")
plt.ylabel("Anzahl Nachrichten")
plt.grid(True)
plt.show()

# %%
def keyword_trend(keyword):
    df_news['has_keyword'] = df_news['Content'].str.lower().str.contains(fr'\b{keyword}\b', na=False)
    trend = df_news.groupby('Impact Date')['has_keyword'].mean()
    trend.plot(figsize=(12,4), title=f"Keyword-Trend: {keyword}")
    plt.ylabel("Anteil Nachrichten mit Keyword")
    plt.grid(True)
    plt.show()

# Beispiel: Keyword-Analyse für „inflation“
keyword_trend("interest")

# %%
print("==== DEBUG df_news ====")
print("Shape:", df_news.shape)
print("Spaltennamen:", df_news.columns.tolist())
print("Erste Zeilen:")
print(df_news.head())
# Out:
# ==== DEBUG df_news ====
# Shape: (13636, 20)
# Spaltennamen: ['Title', 'Tag', 'Date_x', 'Content', 'Cleaned Content', 'Weekday', 'Impact Date', 'Date_y', 'Open', 'Close', 'Label', 'Change', 'Sma_5', 'Volatility', 'Prev_change', 'Simple Label', 'finbert_sentiment', 'finbert_label', 'text_length', 'has_keyword']
# Erste Zeilen:
#                                                Title                      Tag  \
# 0              TSX Slightly Down, Books Weekly Gains             Stock Market
# 1  US Budget Deficit Widens More than Expected in...  Government Budget Value
# 2                             Visa Hits 24-week High                   stocks
# 3                           Amazon Hits 43-week High                   stocks
# 4       10-Year Treasury Yield Falls for 4th Session      Government Bond 10Y
#
#       Date_x                                            Content  \
# 0 2023-07-16  TSX Slightly Down, Books Weekly GainsUnited St...
# 1 2023-07-14  US Budget Deficit Widens More than Expected in...
# 2 2023-07-14  Visa Hits 24-week HighUnited States stocksVisa...
# 3 2023-07-14  Amazon Hits 43-week HighUnited States stocksAm...
# 4 2023-07-14  10-Year Treasury Yield Falls for 4th SessionUn...
#
#                                      Cleaned Content Weekday Impact Date  \
# 0  [tsx, slightly, books, weekly, gains, united, ...  Sunday  2023-07-17
# 1  [budget, deficit, widens, expected, june, unit...  Friday  2023-07-17
# 2  [visa, hits, week, high, united, states, stock...  Friday  2023-07-17
# 3  [amazon, hits, week, high, united, states, sto...  Friday  2023-07-17
# 4  [year, treasury, yield, falls, session, united...  Friday  2023-07-17
#
#       Date_y          Open         Close  Label   Change         Sma_5  \
# 0 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
# 1 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
# 2 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
# 3 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
# 4 2023-07-17  14149.919922  14244.950195      3 -0.00672  14035.376172
#
#    Volatility  Prev_change Simple Label  \
# 0  193.458381     0.009299     negative
# 1  193.458381     0.009299     negative
# 2  193.458381     0.009299     negative
# 3  193.458381     0.009299     negative
# 4  193.458381     0.009299     negative
#
#                                    finbert_sentiment finbert_label  \
# 0  {'negative': np.float32(0.011293471), 'neutral...       neutral
# 1  {'negative': np.float32(0.6081924), 'neutral':...      negative
# 2  {'negative': np.float32(0.7537409), 'neutral':...      negative
# 3  {'negative': np.float32(0.5418749), 'neutral':...      negative
# 4  {'negative': np.float32(0.018656207), 'neutral...       neutral
#
#    text_length  has_keyword
# 0          956        False
# 1          783        False
# 2           81        False
# 3           85        False
# 4          633        False

# %%
import matplotlib.pyplot as plt

# Sicherstellen, dass Impact Date ein datetime-Format hat
df_news['Impact Date'] = pd.to_datetime(df_news['Impact Date'])

# Monat extrahieren (z. B. "2021-05")
df_news['Month'] = df_news['Impact Date'].dt.to_period('M')

# Neues Feld: enthält Nachricht das Wort "inflation"?
df_news['has_inflation'] = df_news['Content'].str.lower().str.contains(r'\binflation\b', na=False)

# Gruppieren: Wie oft kam "inflation" in einem Monat vor?
monthly_keyword_counts = df_news.groupby('Month')['has_inflation'].sum()




# Annahme: df_price enthält Spalte 'Date' und 'Close'
df_news['Month_y'] = df_news['Date_y'].dt.to_period('M')

# Monatliches Mittel des Schlusskurses
monthly_prices = df_news.groupby('Month')['Close'].mean()

# Monatliche prozentuale Veränderung
monthly_returns = monthly_prices.pct_change()

# DataFrame zusammenbauen
df_analysis = pd.DataFrame({
    'inflation_mentions': monthly_keyword_counts,
    'nasdaq_return': monthly_returns
}).dropna()

# Monat zurück in Timestamp für schöneres Plotten
df_analysis.index = df_analysis.index.to_timestamp()

# Plot
fig, ax1 = plt.subplots(figsize=(15,6))

# Linke Achse: Keyword-Nennungen
ax1.set_xlabel('Monat')
ax1.set_ylabel('Nennungen: "inflation"', color='tab:blue')
ax1.plot(df_analysis.index, df_analysis['inflation_mentions'], color='tab:blue', label='Nennungen "inflation"')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Rechte Achse: Kursveränderung
ax2 = ax1.twinx()
ax2.set_ylabel('NASDAQ Return (%)', color='tab:red')
ax2.plot(df_analysis.index, df_analysis['nasdaq_return'] * 100, color='tab:red', label='NASDAQ Veränderung (%)')
ax2.tick_params(axis='y', labelcolor='tab:red')

# Titel & Layout
plt.title('Zusammenhang: Keyword "inflation" & NASDAQ-Kursentwicklung')
fig.tight_layout()
plt.grid(True)
plt.show()


#In diesem Diagramm wird der Zusammenhang zwischen der Häufigkeit  
#des Keywords „inflation“ in Finanznachrichten und der NASDAQ-Entwicklung dargestellt.

#Die blaue Linie zeigt die Keyword-Nennungen pro Monat,  
#die rote Linie die monatliche NASDAQ-Rendite in Prozent.

# %%
from collections import Counter

# Sicherstellen, dass Impact Date datetime ist
df_news['Impact Date'] = pd.to_datetime(df_news['Impact Date'])

# Neue Spalte für Jahr
df_news['Year'] = df_news['Impact Date'].dt.year

# Container für Jahres-Topwörter
top_words_by_year = {}

for year, group in df_news.groupby('Year'):
    words = []
    group['Cleaned Content'].dropna().apply(lambda tokens: words.extend(tokens))
    word_counts = Counter(words).most_common(5)

    top_words_by_year[str(year)] = {
        f"Top{i+1}_Word": word for i, (word, _) in enumerate(word_counts)
    }
    top_words_by_year[str(year)].update({
        f"Top{i+1}_Count": count for i, (_, count) in enumerate(word_counts)
    })

# DataFrame erstellen
top_words_year_df = pd.DataFrame.from_dict(top_words_by_year, orient='index')
top_words_year_df.index.name = 'Jahr'

# Anzeigen
top_words_year_df
# Out:
#      Top1_Word Top2_Word     Top3_Word Top4_Word Top5_Word  Top1_Count  \
# Jahr
# 2015   percent    united        states     month     index         531
# 2016   percent    states        united    market    points        2072
# 2017   percent    united        states    market    points        2744
# 2018   percent    united        states    market    points        2783
# 2019   percent    united        states    market     month        1555
# 2020    states    united        market    points     stock        2182
# 2021    united    states      earnings       usd    market        2485
# 2022       usd  earnings  expectations    united    states        4516
# 2023    united    states      earnings       usd    market        1574
#
#       Top2_Count  Top3_Count  Top4_Count  Top5_Count
# Jahr
# 2015         422         421         195         154
# 2016        1675        1674         979         974
# 2017        1747        1740         977         922
# 2018        1917        1901        1232         978
# 2019        1131        1117         663         611
# 2020        2082        1236        1200        1112
# 2021        2481        2031        1976        1894
# 2022        4448        3413        3273        3235
# 2023        1551        1136        1109        1048
